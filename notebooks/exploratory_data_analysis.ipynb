# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf

# %%
nav = pd.read_csv("/Users/mg/Documents/quantitative-portfolio-analysis/data/processed/nav_clean.csv")

# %%
open_pos = pd.read_csv("/Users/mg/Documents/quantitative-portfolio-analysis/data/processed/open_positions_clean.csv")

# %%
trades = pd.read_csv("/Users/mg/Documents/quantitative-portfolio-analysis/data/processed/trades_clean.csv")
